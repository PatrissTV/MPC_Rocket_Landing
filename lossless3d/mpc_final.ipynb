# %%
# %run basic_material
import numpy as np
import matplotlib.pyplot as plt
from modules.NMPC_mass import MPC
#from modules.NMPC_nolossless import MPC
from modules.Tracking import Tracking
import time
import pylab as pl
from IPython import display
from scipy.integrate import solve_ivp

#np.set_printoptions(precision=3,suppress=True)
# Out:
# Running Python: 3.11.3

# %%
Cd = 0.0
mpc = MPC()
x0 = [40,0,100,-1,-2,0,-60]
#x0 = [30,-20,50,-1,-2,40]
mpc.Cd = Cd
mpc.alpha = 0.1

# %%
mpc.initialize()

# %%
u = np.array([[0,0,3]]).T
mpc_nominal = mpc.run(x0,u)
mpc.nicePlot()
mpc.plot3d()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 1310
#   Number of variables: 1505
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 1.738481044769287
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
